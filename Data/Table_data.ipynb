# %% [markdown]
# # Table Creation

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import json
import re

# %% [markdown]
# ## Data

# %%
# Read cvs file using pandas
table_df = pd.read_csv('table_data.csv')
table_df
# Out:
#      Model_Year         Make                   Model   MPG  Cylinders  \
# 0          1970  Rolls Royce           Silver Shadow  11.0          8
# 1          1970      Peugeot                     504  25.0          4
# 2          1970         Audi                  100 Ls  24.0          4
# 3          1970          Bmw                    2002  26.0          4
# 4          1970   Volkswagen       1131 Deluxe Sedan  26.0          4
# ..          ...          ...                     ...   ...        ...
# 404        1982      Mercury                  Lynx L  36.0          4
# 405        1982   Oldsmobile  Cutlass Ciera (Diesel)  38.0          6
# 406        1982     Plymouth           Horizon Miser  38.0          4
# 407        1982      Pontiac      J2000 Se Hatchback  31.0          4
# 408        1982      Pontiac                Phoenix   27.0          4
#
#      Displacement  Horsepower  Acceleration  Weight        Country
# ...

# %%
table_df = table_df.astype(str,copy=False)

# %%
table_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Model_Year    409 non-null    object
#  1   Make          409 non-null    object
#  2   Model         409 non-null    object
#  3   MPG           409 non-null    object
#  4   Cylinders     409 non-null    object
#  5   Displacement  409 non-null    object
#  6   Horsepower    409 non-null    object
#  7   Acceleration  409 non-null    object
#  8   Weight        409 non-null    object
#  9   Country       409 non-null    object
# dtypes: object(10)
# memory usage: 32.1+ KB

# %%
#tabledata_js = table_df.to_json('data.js', orient='records')

# %%
data = pd.read_json('data.js')
data
# Out:
#                         0        1        2        3                  4    \
# Model_Year             1970     1970     1970     1970               1970
# Make            Rolls Royce  Peugeot     Audi      Bmw         Volkswagen
# Model         Silver Shadow      504   100 Ls     2002  1131 Deluxe Sedan
# MPG                    11.0     25.0     24.0     26.0               26.0
# Cylinders                 8        4        4        4                  4
# Displacement          380.0    110.0    107.0    121.0               97.0
# Horsepower              189       87       90      113                 46
# Acceleration           11.0     17.5     14.5     12.5               20.5
# Weight                 4648     2672     2430     2234               1835
# Country             England   France  Germany  Germany            Germany
#
#                  5               6       7              8               9    \
# Model_Year      1970            1970    1970           1970            1970
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Model_Year to Country
# Columns: 409 entries, 0 to 408
# dtypes: object(409)
# memory usage: 32.0+ KB
