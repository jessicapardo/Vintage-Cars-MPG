# %%
import pandas as pd

# %%
df = pd.read_csv("../../../Data/clean_auto-mpg.csv")

# %%
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    16.0          8         304.0         150    3433          12.0
# 1    15.0          8         390.0         190    3850           8.5
# 2    18.0          6         199.0          97    2774          15.5
# 3    21.0          6         199.0          90    2648          15.0
# 4    18.0          6         258.0         110    2962          13.5
# ..    ...        ...           ...         ...     ...           ...
# 404  19.0          4         121.0         112    2868          15.5
# 405  22.0          4         121.0          98    2945          14.5
# 406  20.0          4         130.0         102    3150          15.7
# 407  17.0          6         163.0         125    3140          13.6
# 408  30.7          6         145.0          76    3160          19.6
#
#      Model Year  Origin   Make                   Model        Country
# ...

# %%
df['Model'] = df['Model'].str.capitalize()
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    16.0          8         304.0         150    3433          12.0
# 1    15.0          8         390.0         190    3850           8.5
# 2    18.0          6         199.0          97    2774          15.5
# 3    21.0          6         199.0          90    2648          15.0
# 4    18.0          6         258.0         110    2962          13.5
# ..    ...        ...           ...         ...     ...           ...
# 404  19.0          4         121.0         112    2868          15.5
# 405  22.0          4         121.0          98    2945          14.5
# 406  20.0          4         130.0         102    3150          15.7
# 407  17.0          6         163.0         125    3140          13.6
# 408  30.7          6         145.0          76    3160          19.6
#
#      Model Year  Origin   Make                   Model        Country
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    16.0          8         304.0         150    3433          12.0
# 1    15.0          8         390.0         190    3850           8.5
# 2    18.0          6         199.0          97    2774          15.5
# 3    21.0          6         199.0          90    2648          15.0
# 4    18.0          6         258.0         110    2962          13.5
# ..    ...        ...           ...         ...     ...           ...
# 404  19.0          4         121.0         112    2868          15.5
# 405  22.0          4         121.0          98    2945          14.5
# 406  20.0          4         130.0         102    3150          15.7
# 407  17.0          6         163.0         125    3140          13.6
# 408  30.7          6         145.0          76    3160          19.6
#
#      Model Year  Origin   Make                   Model        Country
# ...

# %%
df.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>MPG</th>\n      <th>Cylinders</th>\n      <th>Displacement</th>\n      <th>Horsepower</th>\n      <th>Weight</th>\n      <th>Acceleration</th>\n      <th>Model Year</th>\n      <th>Origin</th>\n      <th>Make</th>\n      <th>Model</th>\n      <th>Country</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>16.0</td>\n      <td>8</td>\n      <td>304.0</td>\n      <td>150</td>\n      <td>3433</td>\n      <td>12.0</td>\n      <td>70</td>\n      <td>1</td>\n      <td>AMC</td>\n      <td>Rebel sst</td>\n      <td>United States</td>\n    </tr>\n    <tr>\n      <td>15.0</td>\n      <td>8</td>\n      <td>390.0</td>\n      <td>190</td>\n      <td>3850</td>\n      <td>8.5</td>\n      <td>70</td>\n      <td>1</td>\n      <td>AMC</td>\n      <td>Ambassador dpl</td>\n      <td>United States</td>\n    </tr>\n    <tr>\n      <td>18.0</td>\n      <td>6</td>\n      <td>199.0</td>\n      <td>97</td>
# ...

# %%
df.to_json("data_jsonified.json", orient = "records")
